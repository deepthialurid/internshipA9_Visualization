# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("readmission.csv")
df
# Out:
#       encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0          2278392      8222157        Caucasian  ...     No          No         NO
# 1           149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2            64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3           500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4            16680     42519267        Caucasian  ...     Ch         Yes         NO
# ...            ...          ...              ...  ...    ...         ...        ...
# 5530      28602342     18290736        Caucasian  ...     No         Yes         NO
# 5531      28602708     23063220        Caucasian  ...     No         Yes        >30
# 5532      28603266     73167606  AfricanAmerican  ...     No          No        >30
# 5533      28603704     13377636  AfricanAmerican  ...     No         Yes        >30
# ...

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0       2278392      8222157        Caucasian  ...     No          No         NO
# 1        149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2         64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3        500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4         16680     42519267        Caucasian  ...     Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  ...  number_inpatient  number_diagnoses
# count  5.535000e+03  5.535000e+03  ...       5534.000000       5534.000000
# mean   1.665572e+07  2.514142e+07  ...          0.410553          6.752620
# std    8.185705e+06  3.399057e+07  ...          0.930945          2.075754
# min    1.252200e+04  1.350000e+02  ...          0.000000          1.000000
# 25%    9.568929e+06  1.721516e+06  ...          0.000000          5.000000
# 50%    1.772083e+07  6.048450e+06  ...          0.000000          7.000000
# 75%    2.410931e+07  3.248072e+07  ...          0.000000          9.000000
# max    2.860530e+07  1.151968e+08  ...         15.000000          9.000000
#
# [8 rows x 13 columns]

# %%
df.cov()
# Out:
#                           encounter_id  ...  number_diagnoses
# encounter_id              6.700576e+13  ...     220133.418272
# patient_nbr              -1.073976e+13  ...    -280207.650958
# admission_type_id        -4.282284e+06  ...         -0.608487
# discharge_disposition_id -2.689931e+07  ...          0.047083
# admission_source_id       6.752349e+06  ...          0.919206
# time_in_hospital          3.962316e+05  ...          1.899366
# num_lab_procedures       -1.771407e+07  ...          8.413106
# num_procedures           -9.167156e+05  ...          0.503295
# num_medications           5.672753e+05  ...          4.876727
# number_outpatient        -1.759127e+04  ...          0.033204
# number_emergency          1.099469e+05  ...          0.004217
# number_inpatient          5.167004e+05  ...          0.240384
# number_diagnoses          2.201334e+05  ...          4.308754
#
# [13 rows x 13 columns]

# %%
df.corr()
# Out:
#                           encounter_id  ...  number_diagnoses
# encounter_id                  1.000000  ...          0.012957
# patient_nbr                  -0.038599  ...         -0.003971
# admission_type_id            -0.265357  ...         -0.148698
# discharge_disposition_id     -0.453612  ...          0.003131
# admission_source_id           0.164973  ...          0.088590
# time_in_hospital              0.015486  ...          0.292781
# num_lab_procedures           -0.120185  ...          0.225101
# num_procedures               -0.062862  ...          0.136088
# num_medications               0.008946  ...          0.303243
# number_outpatient            -0.004404  ...          0.032775
# number_emergency              0.052925  ...          0.008004
# number_inpatient              0.067811  ...          0.124396
# number_diagnoses              0.012957  ...          1.000000
#
# [13 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.dtypes
# Out:
# encounter_id                  int64
# patient_nbr                   int64
# race                         object
# gender                       object
# age                          object
# weight                       object
# admission_type_id             int64
# discharge_disposition_id      int64
# admission_source_id           int64
# time_in_hospital              int64
# payer_code                   object
# medical_specialty            object
# num_lab_procedures            int64
# num_procedures                int64
# num_medications             float64
# number_outpatient           float64
# number_emergency            float64
# number_inpatient            float64
# diag_1                       object
# diag_2                       object
# diag_3                       object
# number_diagnoses            float64
# max_glu_serum                object
# A1Cresult                    object
# metformin                    object
# repaglinide                  object
# ...

# %%
import matplotlib
# %matplotlib inline

# %%
df['diag_1'].hist(bins=10)

# %%
df['diag_2'].hist(bins=10)

# %%
df['diag_3'].hist(bins=10)

# %%
df['number_diagnoses'].hist(bins=10)

# %%
df['max_glu_serum'].hist(bins=10)

# %%
df['A1Cresult'].hist(bins=10)

# %%
df['insulin'].hist(bins=10)

# %%
df['diabetesMed'].hist(bins=10)

# %%
df['readmitted'].hist(bins=10)

# %%
df.boxplot(column='number_diagnoses')

# %%
df.boxplot(column='readmitted')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1bed9e20c2d8> in <module>
# ----> 1 df.boxplot(column='readmitted')
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
sns.heatmap(df.corr())

# %%
df.isnull()
# Out:
#       encounter_id  patient_nbr   race  ...  change  diabetesMed  readmitted
# 0            False        False  False  ...   False        False       False
# 1            False        False  False  ...   False        False       False
# 2            False        False  False  ...   False        False       False
# 3            False        False  False  ...   False        False       False
# 4            False        False  False  ...   False        False       False
# ...            ...          ...    ...  ...     ...          ...         ...
# 5530         False        False  False  ...   False        False       False
# 5531         False        False  False  ...   False        False       False
# 5532         False        False  False  ...   False        False       False
# 5533         False        False  False  ...   False        False       False
# 5534         False        False  False  ...    True         True        True
#
# [5535 rows x 50 columns]

# %%
df['diabetesMed'].value_counts()
# Out:
# Yes    4224
# No     1310
# Name: diabetesMed, dtype: int64

# %%
df['readmitted'].value_counts()
# Out:
# NO     2741
# >30    2185
# <30     608
# Name: readmitted, dtype: int64

# %%
sns.jointplot(df['insulin'],df['number_diagnoses'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4c33b1df80a0> in <module>
# ----> 1 sns.jointplot(df['insulin'],df['number_diagnoses'])
#
# NameError: name 'sns' is not defined

# %%
#scatter plot
plt.scatter(df['number_diagnoses'],df['number_emergency'],color='g')
plt.title("Numerical Feature: number_diagnoses v/s number_emergency")
plt.xlabel("number_diagnoses")
plt.ylabel("number_emergency")
# Out:
# Text(0, 0.5, 'number_emergency')

# %%
#scatter plot
plt.scatter(df['number_inpatient'],df['num_medications'],color='y')
plt.title("Numerical Feature: number_inpatient v/s num_medications")
plt.xlabel("number_inpatient")
plt.ylabel("num_medications")
# Out:
# Text(0, 0.5, 'num_medications')

# %%
sns.jointplot(df['number_diagnoses'],df['number_emergency'])
